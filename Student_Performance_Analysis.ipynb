# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3e1381f-68fe-4df8-944f-76104cb2d1bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3e1381f-68fe-4df8-944f-76104cb2d1bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('student_marks.csv')

df.head()
# Out:
#   Student  Tamil  English  Maths  Science  Computer
# 0    Arun     85       78     92       88        90
# 1   Priya     95       89     97       94        96
# 2  Kaviya     45       50     38       42        55
# 3    Mani     67       72     60       65        70
# 4     Ram     30       40     35       28        45

# %%
def grade(avg):
    if avg >= 90:
        return 'A'
    elif avg >= 75:
        return 'B'
    elif avg >= 50:
        return 'C'
    else:
        return 'D'

df['Grade'] = df['Average'].apply(grade)

df[['Student','Average','Grade']].head()
# Out:
#   Student  Average Grade
# 0    Arun     86.6     B
# 1   Priya     94.2     A
# 2  Kaviya     46.0     D
# 3    Mani     66.8     C
# 4     Ram     35.6     D

# %%
df['Status'] = df['Average'].apply(lambda x: 'Pass' if x >= 40 else 'Fail')

df[['Student','Status']].head()
# Out:
#   Student Status
# 0    Arun   Pass
# 1   Priya   Pass
# 2  Kaviya   Pass
# 3    Mani   Pass
# 4     Ram   Fail

# %%
topper = df.loc[df['Average'].idxmax()]

print("Topper Details")
print(topper)
# Out:
# Topper Details
# Student     Mohan
# Tamil         100
# English       100
# Maths         100
# Science       100
# Computer      100
# Average     100.0
# Grade           A
# Status       Pass
# Name: 24, dtype: object

# %%
subject_avg = df[subjects].mean()

subject_avg.plot(kind='bar')

plt.title('Subject Wise Average Marks')
plt.xlabel('Subjects')
plt.ylabel('Marks')

plt.show()

# %%
status_count = df['Status'].value_counts()

plt.pie(status_count,
        labels=status_count.index,
        autopct='%1.1f%%')

plt.title('Pass vs Fail')

plt.show()

# %%
top5 = df.sort_values(by='Average', ascending=False)

top5[['Student','Average']].head()
# Out:
#    Student  Average
# 24   Mohan    100.0
# 30  Harini     97.0
# 25  Yamuna     95.4
# 1    Priya     94.2
# 21   Pooja     94.0

# %%
df.to_csv('final_student_analysis.csv', index=False)

print("Project Completed Successfully")
# Out:
# Project Completed Successfully

# %%
print("""
The Student Performance Analysis project successfully analyzed
student marks using Python. The project identified toppers,
calculated grades, generated pass/fail reports, and created
visualizations for better understanding of student performance.
""")
# Out:
# The Student Performance Analysis project successfully analyzed
# student marks using Python. The project identified toppers,
# calculated grades, generated pass/fail reports, and created
# visualizations for better understanding of student performance.
